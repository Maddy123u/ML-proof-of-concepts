# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# Data collection

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3607f08c-4a5f-4c10-9dba-053d98a7492d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3607f08c-4a5f-4c10-9dba-053d98a7492d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Data preprocessing

# %%
ban = pd.read_csv('/content/bank.csv')
ban
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
ban.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
ban.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
ban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %%
ban.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
ban.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  4521.000000   4521.000000  4521.000000  4521.000000  4521.000000
# mean     41.170095   1422.657819    15.915284   263.961292     2.793630
# std      10.576211   3009.638142     8.247667   259.856633     3.109807
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#              pdays     previous
# count  4521.000000  4521.000000
# mean     39.766645     0.542579
# std     100.121124     1.693562
# min      -1.000000     0.000000
# 25%      -1.000000     0.000000
# 50%      -1.000000     0.000000
# 75%      -1.000000     0.000000
# max     871.000000    25.000000

# %%
ban.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# LabelEncoding

# %%
ban['contact'].nunique()
# Out:
# 3

# %%
ban['job'].nunique()
# Out:
# 12

# %%
ban['marital'].nunique()
# Out:
# 3

# %%
ban['education'].nunique()
# Out:
# 4

# %%
ban['default'].nunique()
# Out:
# 2

# %%
ban['housing'].nunique()
# Out:
# 2

# %%
ban['poutcome'].nunique()
# Out:
# 4

# %%
ban['y'].nunique()
# Out:
# 2

# %%
from sklearn.preprocessing import LabelEncoder

# List of your 14 categorical columns
categorical_columns = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome','y']

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Iterate through the categorical columns and apply label encoding to each
for column in categorical_columns:
    ban[column] = label_encoder.fit_transform(ban[column])

# %%
ban #o-no 1-yes
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      30   10        1          0        0     1787        0     0        0
# 1      33    7        1          1        0     4789        1     1        0
# 2      35    4        2          2        0     1350        1     0        0
# 3      30    4        1          2        0     1476        1     1        2
# 4      59    1        1          1        0        0        1     0        2
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 4516   33    7        1          1        0     -333        1     0        0
# 4517   57    6        1          2        1    -3313        1     1        2
# 4518   57    9        1          1        0      295        0     0        0
# 4519   28    1        1          1        0     1137        0     0        0
# 4520   44    2        2          2        0     1136        1     1        0
#
# ...

# %%
ban = ban.drop(columns = ['day','month'],axis = 1)
ban
# Out:
#       age  job  marital  education  default  balance  housing  loan  contact  \
# 0      30   10        1          0        0     1787        0     0        0
# 1      33    7        1          1        0     4789        1     1        0
# 2      35    4        2          2        0     1350        1     0        0
# 3      30    4        1          2        0     1476        1     1        2
# 4      59    1        1          1        0        0        1     0        2
# ...   ...  ...      ...        ...      ...      ...      ...   ...      ...
# 4516   33    7        1          1        0     -333        1     0        0
# 4517   57    6        1          2        1    -3313        1     1        2
# 4518   57    9        1          1        0      295        0     0        0
# 4519   28    1        1          1        0     1137        0     0        0
# 4520   44    2        2          2        0     1136        1     1        0
#
# ...

# %% [markdown]
# Data standardisation

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()

# List of all columns in your DataFrame that you want to standardize
columns_to_scale = ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'duration', 'campaign', 'pdays','previous', 'poutcome']

# Apply standard scaling to each column
for column in columns_to_scale:
    ban[column] = scaler.fit_transform(ban[[column]])

# %%
ban
# Out:
#            age       job   marital  education   default   balance   housing  \
# 0    -1.056270  1.716804 -0.246429  -1.644755 -0.130759  0.121072 -1.142051
# 1    -0.772583  0.795246 -0.246429  -0.309038 -0.130759  1.118644  0.875617
# 2    -0.583458 -0.126313  1.421396   1.026680 -0.130759 -0.024144  0.875617
# 3    -1.056270 -0.126313 -0.246429   1.026680 -0.130759  0.017726  0.875617
# 4     1.686036 -1.047871 -0.246429  -0.309038 -0.130759 -0.472753  0.875617
# ...        ...       ...       ...        ...       ...       ...       ...
# 4516 -0.772583  0.795246 -0.246429  -0.309038 -0.130759 -0.583410  0.875617
# 4517  1.496912  0.488060 -0.246429   1.026680  7.647669 -1.573671  0.875617
# 4518  1.496912  1.409618 -0.246429  -0.309038 -0.130759 -0.374724 -1.142051
# 4519 -1.245394 -1.047871 -0.246429  -0.309038 -0.130759 -0.094925 -1.142051
# 4520  0.267602 -0.740685  1.421396   1.026680 -0.130759 -0.095257  0.875617
#
# ...

# %% [markdown]
# Data sampling

# %%
x = ban.drop(columns = 'y',axis = 1)
y = ban['y']

# %%
x1 = x[0:905]
y1 = y[0:905]
x2 = x[905:1809]
y2 = y[905:1809]
x3 = x[1809:2713]
y3 = y[1809:2713]
x4 = x[2713:3617]
y4 = y[2713:3617]
x5 = x[3617:4521]
y5 = y[3617:4521]

# %%
x1
# Out:
#           age       job   marital  education   default   balance   housing  \
# 0   -1.056270  1.716804 -0.246429  -1.644755 -0.130759  0.121072 -1.142051
# 2717 -1.150832  1.409618  1.421396   1.026680 -0.130759  0.299851 -1.142051
# ...        ...       ...       ...        ...       ...       ...       ...
# 3612  0.834976 -0.126313 -1.914255   1.026680 -0.130759 -0.354453 -1.142051
# 3613  0.740414  1.409618 -0.246429  -0.309038 -0.130759  0.430446 -1.142051
# 3614  2.820784  0.180874 -1.914255   1.026680 -0.130759 -0.386022 -1.142051
# 3615 -0.961707 -1.355057  1.421396  -0.309038 -0.130759 -0.221200 -1.142051
# 3616  0.362165 -0.126313  1.421396   1.026680 -0.130759 -0.467436 -1.142051
#
# ...

# %%
x5
# Out:
#            age       job   marital  education   default   balance   housing  \
# 3617  0.078478 -1.047871 -0.246429  -0.309038 -0.130759 -0.612985 -1.142051
# 3618  0.362165 -1.355057 -0.246429  -0.309038 -0.130759 -0.390342 -1.142051
# 3619  0.551289  1.409618 -0.246429  -1.644755 -0.130759 -0.424569  0.875617
# 3620  1.780599  0.180874 -1.914255  -0.309038 -0.130759 -0.274036 -1.142051
# 3621 -0.583458 -0.126313 -0.246429   1.026680 -0.130759 -0.157398  0.875617
# ...        ...       ...       ...        ...       ...       ...       ...
# 4516 -0.772583  0.795246 -0.246429  -0.309038 -0.130759 -0.583410  0.875617
# 4517  1.496912  0.488060 -0.246429   1.026680  7.647669 -1.573671  0.875617
# 4518  1.496912  1.409618 -0.246429  -0.309038 -0.130759 -0.374724 -1.142051
# 4519 -1.245394 -1.047871 -0.246429  -0.309038 -0.130759 -0.094925 -1.142051
# 4520  0.267602 -0.740685  1.421396   1.026680 -0.130759 -0.095257  0.875617
#
# ...

# %%
sns.countplot(x='y',data = ban)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
sns.boxplot(x='job',data = ban)
# Out:
# <Axes: xlabel='job'>

# %% [markdown]
# Model training and evaluation

# %%
from sklearn.model_selection import train_test_split as tts
xtrain,xtest,ytrain,ytest = tts(x1,y1,test_size = 0.2)

# %%
print(xtrain.shape,xtest.shape,ytrain.shape,ytest.shape)
# Out:
# (724, 14) (181, 14) (724,) (181,)

# %% [markdown]
# Training 1

# %%
from sklearn.linear_model import LogisticRegression as lr
model = lr()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score as asi
acc = model.predict(xtest)
print("accuracy score is:",(asi(ytest,acc))*100)
# Out:
# accuracy score is: 85.6353591160221

# %% [markdown]
# Training 2

# %%
acc1 = model.predict(x2)
print("accuracy score is:",(asi(y2,acc1))*100)
# Out:
# accuracy score is: 88.16371681415929

# %% [markdown]
# Training 3

# %%
acc2 = model.predict(x3)
print("accuracy score is:",(asi(y3,acc2))*100)
# Out:
# accuracy score is: 89.15929203539822

# %% [markdown]
# Training 4

# %%
acc3 = model.predict(x4)
print("accuracy score is:",(asi(y4,acc3))*100)
# Out:
# accuracy score is: 89.38053097345133

# %% [markdown]
# Training 5

# %%
acc4 = model.predict(x5)
print("accuracy score is:",(asi(y5,acc4))*100)
# Out:
# accuracy score is: 87.83185840707965

# %% [markdown]
# Making a predictive system

# %%
inp = [54	,2	,2	,2	,0	,1457	,1,	1	,1	,345	,2,	367,	5	,1]
arr = np.asarray(inp)
shap = arr.reshape(1,-1)
shap = scaler.fit_transform(shap)
ac = model.predict(shap)
print(ac)
if ac == 0:
  print("the term deposit is not subscribed")
else:
  print("the term deposit is subscribed")
# Out:
# [0]
# the term deposit is not subscribed
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
